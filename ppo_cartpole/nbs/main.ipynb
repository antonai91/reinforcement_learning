# %%
import sys
sys.path.append("../src/")
from config import *
#from pong_wrapper import *
#from process_image import *
import gym
from utilities import *
from a2c_networks import *
from a2c_agent import *

# %%
pw = gym.make(ENV_NAME)
model = Model(num_actions=pw.action_space.n, hidden=HIDDEN)
agent = A2CAgent(model, load_path=PATH_LOAD_MODEL)

# %%
agent.train(pw)
# Out:
# {'Game number': 1, '# Update': 0, '% Update': 0.0, 'Reward': 11.0, 'Time taken': 0.05}
# {'Game number': 2, '# Update': 0, '% Update': 0.0, 'Reward': 15.0, 'Time taken': 0.06}
# {'Game number': 3, '# Update': 0, '% Update': 0.0, 'Reward': 15.0, 'Time taken': 0.07}
# {'Game number': 4, '# Update': 0, '% Update': 0.0, 'Reward': 10.0, 'Time taken': 0.08}
# {'Game number': 5, '# Update': 1, '% Update': 0.0, 'Reward': 17.0, 'Time taken': 0.0}
# {'Game number': 6, '# Update': 1, '% Update': 0.0, 'Reward': 12.0, 'Time taken': 0.02}
# {'Game number': 7, '# Update': 1, '% Update': 0.0, 'Reward': 8.0, 'Time taken': 0.02}
# {'Game number': 8, '# Update': 1, '% Update': 0.0, 'Reward': 10.0, 'Time taken': 0.03}
# {'Game number': 9, '# Update': 1, '% Update': 0.0, 'Reward': 12.0, 'Time taken': 0.04}
# {'Game number': 10, '# Update': 1, '% Update': 0.0, 'Reward': 10.0, 'Time taken': 0.05}
# {'Game number': 11, '# Update': 2, '% Update': 0.0, 'Reward': 9.0, 'Time taken': 0.0}
# ...
